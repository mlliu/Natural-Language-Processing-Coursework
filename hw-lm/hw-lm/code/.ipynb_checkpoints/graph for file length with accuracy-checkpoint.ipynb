# %%
#the helper function is used to plot a graph to show the relationship between file_length with accuracy
#we have four result, gen - gen true positive 0
#.                    gen - spam false negative 1
#                     spam - gen false positive 2
#                     spam - spam true negative 3
def plot_accuracy(file):
    f = open(file,"r")
    lines = f.readlines()
    total_length = [] #length of each file -->x
    total_result = [] #classification result 0,1,2,3 of each file -->y
    
    for line in lines:
        print(line)
        output = line.split('\t')[0].split('.')[0] #the classification result
        right = line.split('\t')[1]
        label = right.split('/')[4]#the true lable
        length = int(right.split('/')[5].split('.')[1]) # the length of the file
        print(output,label,length)
        total_length.append(length)
        if output == label == "gen":
            total_result.append(0)
        elif output == "gen" and label == "spam":
            total_result.append(1)
        elif output == "spam" and label == "gen":
            total_result.append(2)
        else:
            total_result.append(3)
    print(total_length,total_result)

# %%
file = "gen_spam_accuracy"
plot_accuracy(file)
# Out:
# gen.model	../data/gen_spam/dev/gen/gen.10.158.txt
#
# gen gen 10
# gen.model	../data/gen_spam/dev/gen/gen.101.156.txt
#
# gen gen 101
# gen.model	../data/gen_spam/dev/gen/gen.1026.098.txt
#
# gen gen 1026
# gen.model	../data/gen_spam/dev/gen/gen.1050.064.txt
#
# gen gen 1050
# gen.model	../data/gen_spam/dev/gen/gen.106.120.txt
#
# gen gen 106
# gen.model	../data/gen_spam/dev/gen/gen.1071.116.txt
#
# gen gen 1071
# gen.model	../data/gen_spam/dev/gen/gen.111.119.txt
#
# gen gen 111
# gen.model	../data/gen_spam/dev/gen/gen.113.142.txt
#
# gen gen 113
# gen.model	../data/gen_spam/dev/gen/gen.115.040.txt
#
# gen gen 115
# gen.model	../data/gen_spam/dev/gen/gen.115.169.txt
#
# gen gen 115
# gen.model	../data/gen_spam/dev/gen/gen.116.154.txt
#
# gen gen 116
# gen.model	../data/gen_spam/dev/gen/gen.1165.139.txt
#
# gen gen 1165
# gen.model	../data/gen_spam/dev/gen/gen.118.029.txt
#
# gen gen 118
# spam.model	../data/gen_spam/dev/gen/gen.1208.180.txt
#
# spam gen 1208
# gen.model	../data/gen_spam/dev/gen/gen.1209.083.txt
#
# gen gen 1209
# gen.model	../data/gen_spam/dev/gen/gen.121.009.txt
#
# gen gen 121
# gen.model	../data/gen_spam/dev/gen/gen.121.175.txt
#
# gen gen 121
# gen.model	../data/gen_spam/dev/gen/gen.124.007.txt
#
# gen gen 124
# gen.model	../data/gen_spam/dev/gen/gen.128.099.txt
#
# gen gen 128
# gen.model	../data/gen_spam/dev/gen/gen.128.167.txt
#
# gen gen 128
# gen.model	../data/gen_spam/dev/gen/gen.129.166.txt
#
# gen gen 129
# gen.model	../data/gen_spam/dev/gen/gen.1290.117.txt
#
# gen gen 1290
# gen.model	../data/gen_spam/dev/gen/gen.130.030.txt
#
# gen gen 130
# gen.model	../data/gen_spam/dev/gen/gen.131.110.txt
#
# gen gen 131
# gen.model	../data/gen_spam/dev/gen/gen.132.001.txt
#
# gen gen 132
# gen.model	../data/gen_spam/dev/gen/gen.135.019.txt
#
# gen gen 135
# gen.model	../data/gen_spam/dev/gen/gen.1355.129.txt
#
# gen gen 1355
# gen.model	../data/gen_spam/dev/gen/gen.1388.063.txt
#
# gen gen 1388
# gen.model	../data/gen_spam/dev/gen/gen.141.071.txt
#
# gen gen 141
# gen.model	../data/gen_spam/dev/gen/gen.142.159.txt
#
# gen gen 142
# gen.model	../data/gen_spam/dev/gen/gen.147.021.txt
#
# gen gen 147
# gen.model	../data/gen_spam/dev/gen/gen.147.045.txt
#
# gen gen 147
# gen.model	../data/gen_spam/dev/gen/gen.147.077.txt
#
# gen gen 147
# gen.model	../data/gen_spam/dev/gen/gen.152.126.txt
#
# gen gen 152
# gen.model	../data/gen_spam/dev/gen/gen.153.125.txt
#
# gen gen 153
# gen.model	../data/gen_spam/dev/gen/gen.154.149.txt
#
# gen gen 154
# gen.model	../data/gen_spam/dev/gen/gen.159.069.txt
#
# gen gen 159
# gen.model	../data/gen_spam/dev/gen/gen.16.157.txt
#
# gen gen 16
# gen.model	../data/gen_spam/dev/gen/gen.160.097.txt
#
# gen gen 160
# gen.model	../data/gen_spam/dev/gen/gen.161.150.txt
#
# gen gen 161
# gen.model	../data/gen_spam/dev/gen/gen.163.141.txt
#
# gen gen 163
# gen.model	../data/gen_spam/dev/gen/gen.168.144.txt
#
# gen gen 168
# gen.model	../data/gen_spam/dev/gen/gen.168.152.txt
#
# gen gen 168
# gen.model	../data/gen_spam/dev/gen/gen.170.086.txt
#
# gen gen 170
# gen.model	../data/gen_spam/dev/gen/gen.1715.005.txt
#
# gen gen 1715
# gen.model	../data/gen_spam/dev/gen/gen.173.132.txt
#
# gen gen 173
# gen.model	../data/gen_spam/dev/gen/gen.174.067.txt
#
# gen gen 174
# gen.model	../data/gen_spam/dev/gen/gen.178.073.txt
#
# gen gen 178
# gen.model	../data/gen_spam/dev/gen/gen.181.078.txt
#
# gen gen 181
# gen.model	../data/gen_spam/dev/gen/gen.187.173.txt
#
# gen gen 187
# gen.model	../data/gen_spam/dev/gen/gen.190.155.txt
#
# gen gen 190
# spam.model	../data/gen_spam/dev/gen/gen.195.065.txt
#
# spam gen 195
# gen.model	../data/gen_spam/dev/gen/gen.197.174.txt
#
# gen gen 197
# gen.model	../data/gen_spam/dev/gen/gen.20.059.txt
#
# gen gen 20
# gen.model	../data/gen_spam/dev/gen/gen.21.179.txt
#
# gen gen 21
# gen.model	../data/gen_spam/dev/gen/gen.211.094.txt
#
# gen gen 211
# gen.model	../data/gen_spam/dev/gen/gen.218.049.txt
#
# gen gen 218
# gen.model	../data/gen_spam/dev/gen/gen.22.022.txt
#
# gen gen 22
# gen.model	../data/gen_spam/dev/gen/gen.221.053.txt
#
# gen gen 221
# gen.model	../data/gen_spam/dev/gen/gen.222.089.txt
#
# gen gen 222
# gen.model	../data/gen_spam/dev/gen/gen.230.024.txt
#
# gen gen 230
# gen.model	../data/gen_spam/dev/gen/gen.231.140.txt
#
# gen gen 231
# gen.model	../data/gen_spam/dev/gen/gen.234.151.txt
#
# gen gen 234
# gen.model	../data/gen_spam/dev/gen/gen.236.095.txt
#
# gen gen 236
# gen.model	../data/gen_spam/dev/gen/gen.236.137.txt
#
# gen gen 236
# gen.model	../data/gen_spam/dev/gen/gen.24.010.txt
#
# gen gen 24
# gen.model	../data/gen_spam/dev/gen/gen.24.042.txt
#
# gen gen 24
# gen.model	../data/gen_spam/dev/gen/gen.24.090.txt
#
# gen gen 24
# gen.model	../data/gen_spam/dev/gen/gen.240.172.txt
#
# gen gen 240
# gen.model	../data/gen_spam/dev/gen/gen.25.011.txt
#
# gen gen 25
# gen.model	../data/gen_spam/dev/gen/gen.257.122.txt
#
# gen gen 257
# gen.model	../data/gen_spam/dev/gen/gen.266.054.txt
#
# gen gen 266
# gen.model	../data/gen_spam/dev/gen/gen.266.130.txt
#
# gen gen 266
# gen.model	../data/gen_spam/dev/gen/gen.267.026.txt
#
# gen gen 267
# gen.model	../data/gen_spam/dev/gen/gen.268.020.txt
#
# gen gen 268
# gen.model	../data/gen_spam/dev/gen/gen.268.038.txt
#
# gen gen 268
# gen.model	../data/gen_spam/dev/gen/gen.27.025.txt
#
# gen gen 27
# gen.model	../data/gen_spam/dev/gen/gen.27.047.txt
#
# gen gen 27
# gen.model	../data/gen_spam/dev/gen/gen.275.133.txt
#
# gen gen 275
# gen.model	../data/gen_spam/dev/gen/gen.276.102.txt
#
# gen gen 276
# gen.model	../data/gen_spam/dev/gen/gen.28.072.txt
#
# gen gen 28
# gen.model	../data/gen_spam/dev/gen/gen.280.013.txt
#
# gen gen 280
# gen.model	../data/gen_spam/dev/gen/gen.283.105.txt
#
# gen gen 283
# gen.model	../data/gen_spam/dev/gen/gen.283.170.txt
#
# gen gen 283
# gen.model	../data/gen_spam/dev/gen/gen.29.018.txt
#
# gen gen 29
# gen.model	../data/gen_spam/dev/gen/gen.290.035.txt
#
# gen gen 290
# gen.model	../data/gen_spam/dev/gen/gen.299.092.txt
#
# gen gen 299
# gen.model	../data/gen_spam/dev/gen/gen.30.176.txt
#
# gen gen 30
# gen.model	../data/gen_spam/dev/gen/gen.300.074.txt
#
# gen gen 300
# gen.model	../data/gen_spam/dev/gen/gen.302.039.txt
#
# gen gen 302
# gen.model	../data/gen_spam/dev/gen/gen.302.168.txt
#
# gen gen 302
# gen.model	../data/gen_spam/dev/gen/gen.305.034.txt
#
# gen gen 305
# gen.model	../data/gen_spam/dev/gen/gen.316.052.txt
#
# gen gen 316
# gen.model	../data/gen_spam/dev/gen/gen.320.147.txt
#
# gen gen 320
# gen.model	../data/gen_spam/dev/gen/gen.322.100.txt
#
# gen gen 322
# gen.model	../data/gen_spam/dev/gen/gen.327.112.txt
#
# gen gen 327
# gen.model	../data/gen_spam/dev/gen/gen.328.145.txt
#
# gen gen 328
# gen.model	../data/gen_spam/dev/gen/gen.33.060.txt
#
# gen gen 33
# gen.model	../data/gen_spam/dev/gen/gen.331.017.txt
#
# gen gen 331
# gen.model	../data/gen_spam/dev/gen/gen.331.177.txt
#
# gen gen 331
# gen.model	../data/gen_spam/dev/gen/gen.34.032.txt
#
# gen gen 34
# gen.model	../data/gen_spam/dev/gen/gen.340.046.txt
#
# gen gen 340
# gen.model	../data/gen_spam/dev/gen/gen.345.015.txt
#
# gen gen 345
# gen.model	../data/gen_spam/dev/gen/gen.345.023.txt
#
# gen gen 345
# gen.model	../data/gen_spam/dev/gen/gen.35.084.txt
#
# gen gen 35
# gen.model	../data/gen_spam/dev/gen/gen.35.118.txt
#
# gen gen 35
# gen.model	../data/gen_spam/dev/gen/gen.354.057.txt
#
# gen gen 354
# gen.model	../data/gen_spam/dev/gen/gen.363.036.txt
#
# gen gen 363
# gen.model	../data/gen_spam/dev/gen/gen.368.106.txt
#
# gen gen 368
# gen.model	../data/gen_spam/dev/gen/gen.37.062.txt
#
# gen gen 37
# gen.model	../data/gen_spam/dev/gen/gen.371.123.txt
#
# gen gen 371
# gen.model	../data/gen_spam/dev/gen/gen.38.161.txt
#
# gen gen 38
# gen.model	../data/gen_spam/dev/gen/gen.39.051.txt
#
# gen gen 39
# gen.model	../data/gen_spam/dev/gen/gen.40.162.txt
#
# gen gen 40
# gen.model	../data/gen_spam/dev/gen/gen.404.016.txt
#
# gen gen 404
# gen.model	../data/gen_spam/dev/gen/gen.433.101.txt
#
# gen gen 433
# gen.model	../data/gen_spam/dev/gen/gen.44.160.txt
#
# gen gen 44
# gen.model	../data/gen_spam/dev/gen/gen.445.080.txt
#
# gen gen 445
# gen.model	../data/gen_spam/dev/gen/gen.447.031.txt
#
# gen gen 447
# gen.model	../data/gen_spam/dev/gen/gen.448.111.txt
#
# gen gen 448
# gen.model	../data/gen_spam/dev/gen/gen.449.056.txt
#
# gen gen 449
# gen.model	../data/gen_spam/dev/gen/gen.45.075.txt
#
# gen gen 45
# gen.model	../data/gen_spam/dev/gen/gen.451.163.txt
#
# gen gen 451
# gen.model	../data/gen_spam/dev/gen/gen.47.070.txt
#
# gen gen 47
# gen.model	../data/gen_spam/dev/gen/gen.47.178.txt
#
# gen gen 47
# gen.model	../data/gen_spam/dev/gen/gen.471.027.txt
#
# gen gen 471
# gen.model	../data/gen_spam/dev/gen/gen.48.165.txt
#
# gen gen 48
# gen.model	../data/gen_spam/dev/gen/gen.492.121.txt
#
# gen gen 492
# gen.model	../data/gen_spam/dev/gen/gen.50.004.txt
#
# gen gen 50
# gen.model	../data/gen_spam/dev/gen/gen.50.033.txt
#
# gen gen 50
# gen.model	../data/gen_spam/dev/gen/gen.51.146.txt
#
# gen gen 51
# gen.model	../data/gen_spam/dev/gen/gen.526.028.txt
#
# gen gen 526
# gen.model	../data/gen_spam/dev/gen/gen.532.148.txt
#
# gen gen 532
# gen.model	../data/gen_spam/dev/gen/gen.551.044.txt
#
# gen gen 551
# gen.model	../data/gen_spam/dev/gen/gen.56.103.txt
#
# gen gen 56
# gen.model	../data/gen_spam/dev/gen/gen.57.043.txt
#
# gen gen 57
# gen.model	../data/gen_spam/dev/gen/gen.571.003.txt
#
# gen gen 571
# gen.model	../data/gen_spam/dev/gen/gen.59.138.txt
#
# gen gen 59
# gen.model	../data/gen_spam/dev/gen/gen.60.109.txt
#
# gen gen 60
# gen.model	../data/gen_spam/dev/gen/gen.60.114.txt
#
# gen gen 60
# gen.model	../data/gen_spam/dev/gen/gen.60.136.txt
#
# gen gen 60
# gen.model	../data/gen_spam/dev/gen/gen.63.107.txt
#
# gen gen 63
# gen.model	../data/gen_spam/dev/gen/gen.64.153.txt
#
# gen gen 64
# gen.model	../data/gen_spam/dev/gen/gen.643.127.txt
#
# gen gen 643
# gen.model	../data/gen_spam/dev/gen/gen.65.096.txt
#
# gen gen 65
# gen.model	../data/gen_spam/dev/gen/gen.654.079.txt
#
# gen gen 654
# gen.model	../data/gen_spam/dev/gen/gen.66.082.txt
#
# gen gen 66
# gen.model	../data/gen_spam/dev/gen/gen.66.091.txt
#
# gen gen 66
# gen.model	../data/gen_spam/dev/gen/gen.66.143.txt
#
# gen gen 66
# gen.model	../data/gen_spam/dev/gen/gen.660.055.txt
#
# gen gen 660
# gen.model	../data/gen_spam/dev/gen/gen.660.088.txt
#
# gen gen 660
# gen.model	../data/gen_spam/dev/gen/gen.680.164.txt
#
# gen gen 680
# gen.model	../data/gen_spam/dev/gen/gen.69.124.txt
#
# gen gen 69
# gen.model	../data/gen_spam/dev/gen/gen.70.037.txt
#
# gen gen 70
# gen.model	../data/gen_spam/dev/gen/gen.700.048.txt
#
# gen gen 700
# gen.model	../data/gen_spam/dev/gen/gen.71.041.txt
#
# gen gen 71
# gen.model	../data/gen_spam/dev/gen/gen.713.014.txt
#
# gen gen 713
# gen.model	../data/gen_spam/dev/gen/gen.72.058.txt
#
# gen gen 72
# gen.model	../data/gen_spam/dev/gen/gen.76.081.txt
#
# gen gen 76
# gen.model	../data/gen_spam/dev/gen/gen.76.104.txt
#
# gen gen 76
# gen.model	../data/gen_spam/dev/gen/gen.766.115.txt
#
# gen gen 766
# gen.model	../data/gen_spam/dev/gen/gen.78.008.txt
#
# gen gen 78
# gen.model	../data/gen_spam/dev/gen/gen.80.066.txt
#
# gen gen 80
# gen.model	../data/gen_spam/dev/gen/gen.833.108.txt
#
# gen gen 833
# gen.model	../data/gen_spam/dev/gen/gen.86.087.txt
#
# gen gen 86
# gen.model	../data/gen_spam/dev/gen/gen.86.131.txt
#
# gen gen 86
# gen.model	../data/gen_spam/dev/gen/gen.872.002.txt
#
# gen gen 872
# gen.model	../data/gen_spam/dev/gen/gen.9.076.txt
#
# gen gen 9
# gen.model	../data/gen_spam/dev/gen/gen.90.085.txt
#
# gen gen 90
# gen.model	../data/gen_spam/dev/gen/gen.92.135.txt
#
# gen gen 92
# gen.model	../data/gen_spam/dev/gen/gen.93.134.txt
#
# gen gen 93
# gen.model	../data/gen_spam/dev/gen/gen.94.113.txt
#
# gen gen 94
# gen.model	../data/gen_spam/dev/gen/gen.95.050.txt
#
# gen gen 95
# gen.model	../data/gen_spam/dev/gen/gen.95.128.txt
#
# gen gen 95
# gen.model	../data/gen_spam/dev/gen/gen.953.012.txt
#
# gen gen 953
# gen.model	../data/gen_spam/dev/gen/gen.96.068.txt
#
# gen gen 96
# gen.model	../data/gen_spam/dev/gen/gen.96.093.txt
#
# gen gen 96
# gen.model	../data/gen_spam/dev/gen/gen.97.171.txt
#
# gen gen 97
# gen.model	../data/gen_spam/dev/gen/gen.98.006.txt
#
# gen gen 98
# gen.model	../data/gen_spam/dev/gen/gen.98.061.txt
#
# gen gen 98
# 178 files were more probably gen.model (99%)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-1e750dab53e4> in <module>
#       1 file = "gen_accuracy"
# ----> 2 plot_accuracy(file)
#
# <ipython-input-15-7a8465c1b4b0> in plot_accuracy(file)
#      13         print(line)
#      14         output = line.split('\t')[0].split('.')[0] #the classification result
# ---> 15         right = line.split('\t')[1]
#      16         label = right.split('/')[4]#the true lable
#      17         length = int(right.split('/')[5].split('.')[1]) # the length of the file
#
# IndexError: list index out of range
